# %%
import matplotlib.pyplot as plt
import numpy as np

que={"Q1. In 1859, which maths theory about prime numbers was given and is still not proved?":
     [
         "A. Poincaré Theory",
         "B. Fermat’s Last Theorem",
         "C. Riemann Hypothesis",
         "D. Goldbach Conjecture"
     ],
     "Q2. Which natural element melts at the highest temperature?":
     [
         "A. Tungsten",
         "B. Osmium",
         "C. Tantalum",
         "D. Rhenium"
     ],
    "Q3. Which Mughal king built the Moti Masjid inside Delhi’s Red Fort?":
    [
        "A. Akbar",
        "B. Jahangir",
        "C. Shah Jahan",
        "D. Aurangzeb"
    ],
     "Q4. Which space mission first landed a robot (rover) on Mars successfully?":
     [
         "A. Viking 1",
         "B. Pathfinder",
         "C. Curiosity",
         "D. Spirit"
     ],
     "Q5. Which country was earlier called Abyssinia?":
     [
         "A. Eritrea",
         "B. Ethiopia",
         "C. Somalia",
         "D. Sudan"
     ]}
ans=["C","A","D","A","B"]
p=0
r=0
an=[]
c=[]
l=[]
for i,j in que.items():
    print(i)
    print()
    for k in j:
        print(k)
    print()
    answ=input("Enter Your Ans:").upper()
    if answ == ans[r]:
        print("Ans Is Corect 🎉🎉")
        p+=1
        an.append(1)
        c.append("#004225")
    else :
        print("Wrong Ans 😞")
        an.append(-1)
        c.append("#960018")
    print()
    r+=1
print(f"You Point :{p}/5")
q=["Q1","Q2","Q3","Q4","Q5"]
plt.bar(q,an,color=c,edgecolor="#03dffc",hatch="x")
plt.xlabel("---- Question ----")
plt.ylabel("---- Pointe ----")
plt.title("---- Quizizz Score Card ----")

plt.show()
# Out:
# Q1. In 1859, which maths theory about prime numbers was given and is still not proved?
#
# A. Poincaré Theory
# B. Fermat’s Last Theorem
# C. Riemann Hypothesis
# D. Goldbach Conjecture
# Enter Your Ans: a
# Wrong Ans 😞
#
# Q2. Which natural element melts at the highest temperature?
#
# A. Tungsten
# B. Osmium
# C. Tantalum
# D. Rhenium
# Enter Your Ans: b
# Wrong Ans 😞
#
# Q3. Which Mughal king built the Moti Masjid inside Delhi’s Red Fort?
#
# A. Akbar
# B. Jahangir
# C. Shah Jahan
# D. Aurangzeb
# Enter Your Ans: b
# Wrong Ans 😞
#
# Q4. Which space mission first landed a robot (rover) on Mars successfully?
#
# A. Viking 1
# B. Pathfinder
# C. Curiosity
# D. Spirit
# Enter Your Ans: b
# Wrong Ans 😞
#
# Q5. Which country was earlier called Abyssinia?
#
# A. Eritrea
# B. Ethiopia
# C. Somalia
# D. Sudan
# Enter Your Ans: b
# Ans Is Corect 🎉🎉
#
# You Point :1/5
